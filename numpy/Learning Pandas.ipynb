# %% [markdown]
# # Learning Pandas

# %% [markdown]
# Before Pandas, must understand the concept of `Numpy arrays`. Because Pandas is an open source software library which is **built on top of `NumPy`**.
#
# Used for data manipulation, analysis and cleaning, such as:
#
# - Tabular data with heterogeneously-typed columns
# - Ordered and unordered time series data
# - Arbitrary matrix data with row & column labels
# - Unlabelled data
# - Any other form of observational or statistical data sets

# %%
from IPython.display import Image
Image(filename='../img/pandas_operations.png')

# %% [markdown]
# - **_Data Frame_**: it is a 2-dimensional data structure and a most common pandas object.

# %% [markdown]
# **_Slicing the Data Frame_**

# %%
import pandas as pd
 
XYZ_web= {'Day':[1,2,3,4,5,6], "Visitors":[1000, 700,6000,1000,400,350], "Bounce_Rate":[20,20, 23,15,10,34]}
 
df= pd.DataFrame(XYZ_web)                       # convert a dictionary into a pandas Data Frame along with index
 
print(df)
print()
print(df.head(2))                               # slice a particular column from data frame.
print(df.tail(2))                               # last two rows from data frame.
# Out:
#    Bounce_Rate  Day  Visitors
# 0           20    1      1000
# 1           20    2       700
# 2           23    3      6000
# 3           15    4      1000
# 4           10    5       400
# 5           34    6       350
#
#    Bounce_Rate  Day  Visitors
# 0           20    1      1000
# 1           20    2       700

# %% [markdown]
# **_Merging & Joining_**: merge two data frames to form a single data frame.

# %%
import pandas as pd
 
df1= pd.DataFrame({ "HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]}, index=[2001, 2002,2003,2004])
 
df2=pd.DataFrame({ "HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]}, index=[2005, 2006,2007,2008])
 
merged= pd.merge(df1,df2)
 
print(merged)

merged= pd.merge(df1,df2,on ="HPI")  
# specify the column which you want to make common. i.e, I want the “HPI” column to be common and for everything else, I want separate columns.
 
print(merged)


#  join is quite similar to the “merge” operation, except join will be on the “index” instead of  the “columns”.
df1 = pd.DataFrame({"Int_Rate":[2,1,2,3], "IND_GDP":[50,45,45,67]}, index=[2001, 2002,2003,2004])
 
df2 = pd.DataFrame({"Low_Tier_HPI":[50,45,67,34],"Unemployment":[1,3,5,6]}, index=[2001, 2003,2004,2004])
 
joined= df1.join(df2)
print(joined)

# %% [markdown]
# ## Use Case
